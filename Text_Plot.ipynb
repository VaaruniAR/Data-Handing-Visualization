# %% [markdown]
# <a href="https://colab.research.google.com/github/VaaruniAR/Data-Handing-Visualization/blob/main/Text_Plot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
from wordcloud import wordcloud
from collections import Counter
text_data="instagram facebook meta X threads Youtube"
wordcloud = wordcloud.WordCloud(width=800, height=400, background_color='black').generate(text_data)
plt.figure(figsize=(10,5))
plt.imshow(wordcloud)
plt.title('WordCloud')
plt.show()
words=text_data.split()
word_counts=Counter(words)
plt.figure(figsize=(10,5))
plt.bar(word_counts.keys(), word_counts.values())
plt.title('Histogram of word frequencies')
plt.xlabel('words')
plt.ylabel('Frequencies')
plt.xticks(rotation=90)
plt.show()
